# %%
"""
Script 01 — OVL Error sur données agrégées (tous SNRs)
=======================================================

Tâche unique : calculer l'OVL error entre les distributions
réelles (agrégées sur les 6 SNRs) et les distributions simulées par chaque modèle
(Linear, NonLinear1, GainModulation), en 5-fold cross-validation.

Source des données : Distributions_Active_late.csv
    - Modèles utilisés : real et model (snr='all')
    - 20 participants, 5 folds, 3 modèles comparés

Sorties :
    - Affichage console : tableau récapitulatif + test Wilcoxon
    - Figure : boxplot de l'OVL error moyen par modèle (population + individus)
"""

import numpy as np
import pandas as pd
from scipy.stats import gaussian_kde, wilcoxon
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Agg')  # Headless mode
import os

# ─────────────────────────────────────────────────────────────────────────────
# Configuration
# ─────────────────────────────────────────────────────────────────────────────

NOTEBOOK_DIR = '/home/thardy/elefanto/ConsciousnessTeam_Data/SOUNDMODEL/Data_SoundGOOD/LEAD_ExperimentalFolder/SOUNDMODEL_clean'
DATA_PATH = os.path.join(NOTEBOOK_DIR, '../Distributions_Active_late.csv')
OUTPUT_DIR = NOTEBOOK_DIR

MODELS = {
    'linear': 'Linear',
    'nonlinear': 'NonLinear1',
    'gainmodul': 'GainModulation',
}
N_PARTICIPANTS = 20
N_FOLDS = 5


# ─────────────────────────────────────────────────────────────────────────────
# Chargement des données
# ─────────────────────────────────────────────────────────────────────────────

print("Chargement du CSV...")
df = pd.read_csv(DATA_PATH)
data_cols = [c for c in df.columns if c.startswith('idx_')]
print(f"  Shape: {df.shape} | Modèles disponibles: {sorted(df['model'].unique())}")

# ─────────────────────────────────────────────────────────────────────────────
# Agrégation des SNRs : créer des distributions agrégées
# ─────────────────────────────────────────────────────────────────────────────
print("\nAgrégation des SNRs pour créer snr='all'...")
aggregated_distributions = {}
for participant in df['participant'].unique():
    for fold in df['fold'].unique():
        for model in df['model'].unique():
            subset = df[
                (df['participant'] == participant) &
                (df['fold'] == fold) &
                (df['model'] == model)
            ]
            if len(subset) > 0:
                key = (participant, fold, model)
                all_vals = []
                for _, row in subset.iterrows():
                    for col in data_cols:
                        val = pd.to_numeric(row[col], errors='coerce')
                        if not pd.isna(val):
                            all_vals.append(val)
                aggregated_distributions[key] = np.array(all_vals)
print(f"  Agrégation complétée : {len(aggregated_distributions)} combinaisons créées")


def get_distribution(participant, fold, model, snr='all'):
    """Retourne les valeurs agrégées (snr='all') non-NaN."""
    if snr != 'all':
        raise ValueError("Ce notebook utilise uniquement snr='all'.")
    key = (participant, fold, model)
    if key not in aggregated_distributions:
        raise ValueError(f"Aucune donnée pour participant={participant}, fold={fold}, model={model}, snr={snr}")
    return aggregated_distributions[key]


def compute_ovl(real, sim, bw_method='silverman', grid_size=1024):
    """Retourne l'OVL error = 1 - overlap coefficient estimé par KDE."""
    real = np.asarray(real, dtype=float)
    sim = np.asarray(sim, dtype=float)
    real = real[np.isfinite(real)]
    sim = sim[np.isfinite(sim)]
    if len(real) < 2 or len(sim) < 2:
        raise ValueError("OVL requires at least two finite values per sample.")

    kde_real = gaussian_kde(real, bw_method=bw_method)
    kde_sim = gaussian_kde(sim, bw_method=bw_method)

    lower = min(real.min(), sim.min())
    upper = max(real.max(), sim.max())
    padding = 0.05 * (upper - lower if upper > lower else 1.0)
    grid = np.linspace(lower - padding, upper + padding, grid_size)

    overlap = np.trapezoid(np.minimum(kde_real(grid), kde_sim(grid)), grid)
    return float(np.clip(1.0 - overlap, 0.0, 1.0))


# ─────────────────────────────────────────────────────────────────────────────
# Calcul OVL Error par participant et par fold
# ─────────────────────────────────────────────────────────────────────────────

print("\nCalcul OVL_error (bandwidth=Silverman, données agrégées)...")
results = {label: np.zeros((N_PARTICIPANTS, N_FOLDS)) for label in MODELS.values()}

for p in range(N_PARTICIPANTS):
    for f in range(N_FOLDS):
        real = get_distribution(p, f, 'real', snr='all')
        for model_key, model_label in MODELS.items():
            sim = get_distribution(p, f, model_key, snr='all')
            ovl_err = compute_ovl(real, sim)
            results[model_label][p, f] = ovl_err

# ─────────────────────────────────────────────────────────────────────────────
# Agrégation : score par participant = moyenne des 5 folds
# ─────────────────────────────────────────────────────────────────────────────

scores = {label: results[label].mean(axis=1) for label in MODELS.values()}

print("\n=== Résultats OVL agrégé (moyenne sur 5 folds) ===")
print(f"{'Modèle':<20} {'Mean':>8} {'Median':>8} {'Std':>8}")
print("-" * 46)
for label in MODELS.values():
    s = scores[label]
    print(f"{label:<20} {s.mean():>8.4f} {np.median(s):>8.4f} {s.std():>8.4f}")

# ─────────────────────────────────────────────────────────────────────────────
# Tests statistiques : Wilcoxon signé (comparaisons par paires)
# ─────────────────────────────────────────────────────────────────────────────

print("\n=== Tests de Wilcoxon (comparaisons par paires) ===")
model_labels = list(MODELS.values())
for i in range(len(model_labels)):
    for j in range(i + 1, len(model_labels)):
        a, b = model_labels[i], model_labels[j]
        stat, p = wilcoxon(scores[a], scores[b])
        better = a if scores[a].mean() < scores[b].mean() else b
        print(f"  {a} vs {b}: p={p:.4f} — gagne: {better}")

# ─────────────────────────────────────────────────────────────────────────────
# Modèle gagnant par participant
# ─────────────────────────────────────────────────────────────────────────────

print("\n=== Modèle gagnant par participant (OVL error le plus bas) ===")
winner_counts = {label: 0 for label in MODELS.values()}
for p in range(N_PARTICIPANTS):
    winner = min(MODELS.values(), key=lambda m: scores[m][p])
    winner_counts[winner] += 1
    print(f"  P{p:02d}: {winner:<20} (OVL={scores[winner][p]:.4f})")

print(f"\nRécapitulatif : {winner_counts}")

# ─────────────────────────────────────────────────────────────────────────────
# Figure
# ─────────────────────────────────────────────────────────────────────────────

fig, ax = plt.subplots(figsize=(7, 5))
x_labels = list(MODELS.values())
data_to_plot = [scores[label] for label in x_labels]

bp = ax.boxplot(data_to_plot, tick_labels=x_labels, patch_artist=True, notch=False, widths=0.5)
colors = ['#4C72B0', '#DD8452', '#55A868']
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

# Overlay individual participants
for i, label in enumerate(x_labels):
    jitter = np.random.uniform(-0.1, 0.1, N_PARTICIPANTS)
    ax.scatter(np.full(N_PARTICIPANTS, i + 1) + jitter, scores[label],
               color='k', alpha=0.5, s=20, zorder=5)

ax.set_ylabel('OVL error moyen (agrégé)', fontsize=12)
ax.set_title('OVL Error — Données agrégées (tous SNRs)', fontsize=13)
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()

fig_path = os.path.join('/tmp', 'ModelComparison_OVL_result.png')
plt.savefig(fig_path, dpi=150)
print(f"\nFigure sauvegardée : {fig_path}")
plt.close()
# Out:
# Chargement du CSV...
#   Shape: (2400, 5004) | Modèles disponibles: ['gainmodul', 'linear', 'nonlinear', 'real']
#
# Agrégation des SNRs pour créer snr='all'...
#   Agrégation complétée : 400 combinaisons créées
#
# Calcul OVL_error (bandwidth=Silverman, données agrégées)...
#
# === Résultats OVL agrégé (moyenne sur 5 folds) ===
# Modèle                   Mean   Median      Std
# ----------------------------------------------
# Linear                 0.1685   0.1665   0.0218
# NonLinear1             0.1518   0.1506   0.0171
# GainModulation         0.1157   0.1117   0.0180
#
# === Tests de Wilcoxon (comparaisons par paires) ===
#   Linear vs NonLinear1: p=0.0000 — gagne: NonLinear1
#   Linear vs GainModulation: p=0.0000 — gagne: GainModulation
#   NonLinear1 vs GainModulation: p=0.0000 — gagne: GainModulation
#
# === Modèle gagnant par participant (OVL error le plus bas) ===
#   P00: GainModulation       (OVL=0.1312)
#   P01: GainModulation       (OVL=0.1429)
#   P02: GainModulation       (OVL=0.1091)
#   P03: GainModulation       (OVL=0.1442)
#   P04: GainModulation       (OVL=0.1377)
#   P05: GainModulation       (OVL=0.1108)
#   P06: GainModulation       (OVL=0.1124)
#   P07: GainModulation       (OVL=0.0926)
#   P08: GainModulation       (OVL=0.0993)
#   P09: GainModulation       (OVL=0.1395)
#   P10: GainModulation       (OVL=0.1249)
#   P11: GainModulation       (OVL=0.1385)
#   P12: GainModulation       (OVL=0.1000)
#   P13: GainModulation       (OVL=0.0952)
#   P14: GainModulation       (OVL=0.1207)
#   P15: GainModulation       (OVL=0.1003)
#   P16: GainModulation       (OVL=0.0901)
#   P17: GainModulation       (OVL=0.0934)
#   P18: GainModulation       (OVL=0.1194)
#   P19: GainModulation       (OVL=0.1109)
#
# Récapitulatif : {'Linear': 0, 'NonLinear1': 0, 'GainModulation': 20}
#
# Figure sauvegardée : /tmp/ModelComparison_OVL_result.png
#
# [Script 01 terminé]
